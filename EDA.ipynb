# %% [markdown]
# <a href="https://colab.research.google.com/github/vallikumar11/Basic_ML/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### First we have to import pandas as pd,numpy as np and for visualising the data we have to import seaborn,as sns.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# Then we have to import dataset using its path.

# %%
data = pd.read_csv("/content/StudentsPerformance.csv")

# %% [markdown]
# First we have to understand our uploaded data.To see it we have to use data.head().By using it we can see first five lines of data.

# %%
data.head()
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 3    male        group A  ...            57            44
# 4    male        group C  ...            78            75
#
# [5 rows x 8 columns]

# %% [markdown]
# Similarly,we can see last five rows by using data.tail()

# %%
data.tail()
# Out:
#      gender race/ethnicity  ... reading score writing score
# 995  female        group E  ...            99            95
# 996    male        group C  ...            55            55
# 997  female        group C  ...            71            65
# 998  female        group D  ...            78            77
# 999  female        group D  ...            86            86
#
# [5 rows x 8 columns]

# %% [markdown]
# To know number of types under each category,we have to use data.nunique()

# %%
data.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %% [markdown]
# data.describe() describes the data by calcuating mean,std,min,max and different percentages of numeric data.

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# data.isnull().sum() shows the total number of null values(i.e) zeros under each category.

# %%
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# We can remove a category in our data set by using data.drop['  '] by giving the name in ['  ']

# %%
StudentsPerformance =data.drop(['race/ethnicity'],axis = 1)

# %%
StudentsPerformance.head()
# Out:
#    gender parental level of education  ... reading score writing score
# 0  female           bachelor's degree  ...            72            74
# 1  female                some college  ...            90            88
# 2  female             master's degree  ...            95            93
# 3    male          associate's degree  ...            57            44
# 4    male                some college  ...            78            75
#
# [5 rows x 7 columns]

# %% [markdown]
# data.shape(),gives the size of the data.

# %%
data.shape
# Out:
# (1000, 8)

# %% [markdown]
# data['  '].unique() shows the total types under each category.

# %%
data['lunch'].unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %%
data['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
data['parental level of education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
corelation = StudentsPerformance .corr()

# %% [markdown]
# # Heat map

# %% [markdown]
# Now, this visualization style came a long way from simple color-coded tables, it became widely used with geospatial data, and its commonly applied for describing density or intensity of variables, visualize patterns, variance, and even anomalies.

# %%
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)

# %% [markdown]
# # Pair plot

# %% [markdown]
# It is used when we want to show relationship between two variables.

# %%
sns.pairplot(StudentsPerformance)

# %% [markdown]
# # Scatter plot

# %% [markdown]
# A scatter plot (also called a scatterplot, scatter graph, scatter chart, scattergram, or scatter diagram) is a type of plot or mathematical diagram using Cartesian coordinates to display values for typically two variables for a set of data.
# Here we used math score and writing score as criteria,gender as variable.

# %%
sns.relplot(x='math score',y='writing score',hue='gender',data =StudentsPerformance)

# %% [markdown]
# The following scatter plot is about reading score and test preparation course.

# %%
sns.scatterplot(x="test preparation course",y="reading score",data=StudentsPerformance,hue="gender")

# %% [markdown]
# # Histogram

# %% [markdown]
# A histogram is an approximate representation of the distribution of numerical data.
# The following histogram is reading score vs number of students.

# %%
sns.histplot(StudentsPerformance['reading score'])

# %% [markdown]
# The following histogram is math score vs number of students.

# %%
sns.histplot(StudentsPerformance['math score'])

# %% [markdown]
# The following histogram is writing score vs number of students.

# %%
sns.histplot(StudentsPerformance['writing score'])

# %% [markdown]
# The chart shows number of students completed test preparation course.

# %%
sns.displot(StudentsPerformance['test preparation course'])

# %% [markdown]
# The following plot shows education of parents.

# %%
sns.catplot(x="parental level of education", kind="count", data=StudentsPerformance,
            order=["some high school", "high school", "some college", "associate's degree", "bachelor's degree", "master's degree"],
            palette="Set1")

# %% [markdown]
# The followng chart shows about the education of the parents of students.

# %%
sns.histplot(StudentsPerformance['parental level of education'])

# %% [markdown]
# This data set is about marks secured by students in a class,their lunch preference,whether they completed the test perparation course and it also
# contains their parental education.

# %% [markdown]
# # Conclusion
# 1)The strongest correlation is observed between writing and reading marks.
# 2)Male tend to be slightly better at math, while female tend to be noticeably   better at writing and reading.
# 3)Math scores are noticeably lower.
# 4)There are differences between ethnic groups. Average score order is, from worse to better, A->B->C->D->E.
# 5)Not eating before a test is generally not a good idea
# 6)Completing the course is not very useful for having a higher score, but improves your chances to pass.
# 7)It's easier to fail for those who haven't taken the preparatory course.
